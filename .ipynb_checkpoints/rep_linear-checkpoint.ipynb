# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/project_Yuming/codes')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install ipython-autotime
# !pip install torchdiffeq
# !sudo apt install texlive texlive-latex-extra texlive-fonts-recommended dvipng
# !pip install latex
# !sudo apt-get install texlive-latex-extra texlive-fonts-recommended dvipng cm-super
# %load_ext autotime
# %matplotlib inline
# Out:
# time: 1.02 ms (started: 2021-07-14 22:45:44 +00:00)

# %%
import utils
from core_training import train_loop_diff, train_loop_em_new
from viz_loss import loss_grad_vis_1d, loss_grad_vis_2d
# from tqdm import tqdm
from tqdm.auto import tqdm

from models import DEModel, DAModel, NNModel, Noise

# reflect real-time changes in other modules
import importlib
importlib.reload(utils)
importlib.reload(DEModel)
importlib.reload(DAModel)
importlib.reload(NNModel)
importlib.reload(Noise)

from utils import Timer
import copy
import math
import random
import torch
import torch.nn as nn
import numpy as np
from scipy.integrate import solve_ivp
from torchdiffeq import odeint_adjoint
from torchdiffeq import odeint

import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib as mpl
from matplotlib import rc

from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device="cpu"
print(f"device: {device}")
# Out:
# device: cpu
# time: 10.5 s (started: 2021-07-14 22:45:44 +00:00)

# %% [markdown]
# #1. Scaling

# %%
np.rint(np.power(1.2, np.arange(28,70))).astype(int)
# Out:
# array([   165,    198,    237,    285,    342,    410,    492,    591,
#           709,    851,   1021,   1225,   1470,   1764,   2116,   2540,
#          3048,   3657,   4389,   5266,   6320,   7584,   9100,  10921,
#         13105,  15726,  18871,  22645,  27174,  32609,  39130,  46956,
#         56348,  67617,  81140,  97369, 116842, 140211, 168253, 201903,
#        242284, 290741])
# time: 7.02 ms (started: 2021-06-15 01:16:34 +00:00)

# %%
importlib.reload(DAModel)
importlib.reload(NNModel)
importlib.reload(Noise)
importlib.reload(utils)

# seed = 42
# torch.manual_seed(seed)
# np.random.seed(seed)
# random.seed(seed)


# N_ensems = np.rint(np.power(1.2, np.arange(18,50))).astype(int) 
N_ensems = 25 * 2 ** (np.arange(0, 14-2))
n_epochs = N_ensems.shape[0]

n_runs=30
# n_epochs = x_axis.shape[0]

n_metaruns = 1
x_dims = [80]
monitor_EnKFs = []
monitor_KFs = []
monitor_PFs = []

for nm in range(n_metaruns):
  x_dim = x_dims[nm]
  # if nm == 0:
  #   x_dim = x_dims[ne]
  # true_a = torch.tensor(0.42)
  # true_ode_func = NNModel.Linear_ODE_single_var(x_dim, true_a).to(device)
  # true_a = torch.tensor([0.3, 0.4,0.1,0.15,0.05])
  true_a = torch.tensor([0.3, 0.6,0.1])
  a_dim = true_a.shape[0]
  true_ode_func = NNModel.Linear_ODE_diag(x_dim, true_a).to(device)

  u0 = 2*torch.ones(x_dim, device=device)
  t0 = 0.
  t_obs_step = 1.
  t_obs_end = 10.
  t_obs = torch.arange(t0, t_obs_end+t_obs_step, t_obs_step)[1:].to(device)

  # q = 0.5
  # model_Q_true = Noise.AddGaussian(x_dim, torch.sqrt(torch.tensor(q)), "scalar")
  q = 0.5
  model_Q_true = Noise.AddGaussian(x_dim, torch.sqrt(torch.tensor(q)), "scalar", q_shape=torch.tensor(1.))

  init_m = torch.zeros(x_dim, device=device)
  init_C_param = Noise.AddGaussian(x_dim, 4*torch.eye(x_dim), "full")

  indices = [i for i in range(x_dim)]
  # indices = [0]
  y_dim = len(indices)
  H_true = torch.eye(x_dim)[indices]
  true_obs_func = NNModel.Linear(x_dim, y_dim, H_true).to(device)

  noise_R_true = Noise.AddGaussian(y_dim, torch.sqrt(torch.tensor(0.5)), "scalar")

  seed = 42
  torch.manual_seed(seed)
  np.random.seed(seed)
  random.seed(seed)

  with torch.no_grad():
    out, y_obs, out_intermediate, t_intermediate = DEModel.generate_data(true_ode_func, true_obs_func, t_obs, u0, model_Q_true, noise_R_true, 
                                                  device=device, ode_method='euler', ode_options=dict(step_size=t_obs_step), adjoint=False, save_intermediate_step=True, t0=t0, time_varying_obs=False)

  monitor_EnKF = torch.zeros(n_runs, n_epochs, 3+a_dim)
  monitor_PF = torch.zeros(n_runs, n_epochs, 3+a_dim)
  monitor_KF = torch.zeros(1, n_epochs, 3+a_dim)

  for ne in range(n_epochs):
    print(ne,end='') 

    N_ensem = N_ensems[ne]
    # test_a = torch.tensor([0.3, 0.4,0.1,0.15,0.05])
    test_a = torch.tensor([0.3, 0.6, 0.1])
    test_ode_func = NNModel.Linear_ODE_diag(x_dim, test_a).to(device)
    q = 0.5
    test_model_Q = Noise.AddGaussian(x_dim, torch.sqrt(torch.tensor(q)), "scalar", q_shape=torch.tensor(1.))

    enkf_kwargs = dict(ode_method='euler', ode_options=dict(step_size=t_obs_step), adjoint=False, save_intermediate_step=True, smooth_lag=0, t0=t0, 
          var_inflation=None, localization_radius=None, compute_likelihood=True, likelihood_warmup=0, 
          linear_obs=True, time_varying_obs=False, save_first=True, simulation_type=0)

    for nr in range(n_runs):
      X, X_track, X_intermediate, neg_log_likelihood = DAModel.EnKF(test_ode_func, true_obs_func, t_obs, y_obs.unsqueeze(-2).repeat(1,1,1), N_ensem=N_ensem, init_m=init_m, init_C_param=init_C_param, model_Q_param=test_model_Q, noise_R_param=noise_R_true, device=device, detach_every=None, Cf_track=None, **enkf_kwargs)
      neg_log_likelihood.mean().backward()
      monitor_EnKF[nr,ne,0] = neg_log_likelihood.detach()
      monitor_EnKF[nr,ne,1:1+a_dim] = test_ode_func.a.grad.detach()
      monitor_EnKF[nr,ne,1+a_dim] = test_model_Q.post_grad().item()
      monitor_EnKF[nr,ne,2+a_dim] = test_model_Q.q_shape.grad.item()
      test_ode_func.a.grad.zero_()
      test_model_Q.q.grad.zero_()
      test_model_Q.q_shape.grad.zero_()

    m_track, C_track, Cf_track, neg_log_likelihood = DAModel.KF(test_ode_func, true_obs_func, t_obs, y_obs, init_m, init_C_param, test_model_Q, noise_R_true, device, **enkf_kwargs)
    neg_log_likelihood.mean().backward()
    monitor_KF[0,ne,0] = neg_log_likelihood.detach()
    monitor_KF[0,ne,1:1+a_dim] = test_ode_func.a.grad.detach()
    monitor_KF[0,ne,1+a_dim] = test_model_Q.post_grad().item()
    monitor_KF[0,ne,2+a_dim] = test_model_Q.q_shape.grad.item()
    test_ode_func.a.grad.zero_()
    test_model_Q.q.grad.zero_()
    test_model_Q.q_shape.grad.zero_()

    for nr in range(n_runs):
      X, w, X_track, X_intermediate, w_track, w_intermediate, neg_log_likelihood = DAModel.BootstrapPF(test_ode_func, true_obs_func, t_obs, y_obs.unsqueeze(-2).repeat(1,1,1), N_ensem=N_ensem, init_m=init_m, init_C_param=init_C_param, model_Q_param=test_model_Q, noise_R_param=noise_R_true, device=device, proposal='optimal', adaptive_resampling=False, detach_every=None, **enkf_kwargs)
      # X, X_track, X_intermediate, neg_log_likelihood = DAModel.EnKF(test_ode_func, true_obs_func, t_obs, y_obs.unsqueeze(-2).repeat(1,1,1), N_ensem=N_ensem, init_m=init_m, init_C_param=init_C_param, model_Q_param=model_Q_true, noise_R_param=noise_R_true, device=device, detach_every=None, Cf_track=Cf_track, **enkf_kwargs)
      neg_log_likelihood.mean().backward()
      monitor_PF[nr,ne,0] = neg_log_likelihood.detach()
      monitor_PF[nr,ne,1:1+a_dim] = test_ode_func.a.grad.detach()
      monitor_PF[nr,ne,1+a_dim] = test_model_Q.post_grad().item()
      monitor_PF[nr,ne,2+a_dim] = test_model_Q.q_shape.grad.item()
      test_ode_func.a.grad.zero_()
      test_model_Q.q.grad.zero_()
      test_model_Q.q_shape.grad.zero_()

  monitor_EnKFs.append(monitor_EnKF)
  monitor_KFs.append(monitor_KF)
  monitor_PFs.append(monitor_PF)
# Out:
# 01234567891011time: 1min 24s (started: 2021-06-18 18:10:48 +00:00)

# %%
torch.save({'monitor_EnKFs':monitor_EnKFs, 'monitor_KFs':monitor_KFs, 'monitor_PFs':monitor_PFs, 'x_dims':x_dims, 'N_ensems':N_ensems}, 
           f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/20_40_80_off")

# %%
d = torch.load(f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/20_40_80_off")
monitor_EnKFs = d['monitor_EnKFs']
monitor_KFs = d['monitor_KFs']
monitor_PFs = d['monitor_PFs']
x_dims = d['x_dims']
N_ensems = d['N_ensems']
# Out:
# time: 11.8 ms (started: 2021-06-18 04:25:03 +00:00)

# %%
importlib.reload(utils)
mpl.rc_file_defaults()
rc('font', **{'family':'serif','serif':'Computer Modern'})
rc('text', usetex=True)
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']
mpl.rcParams['axes.titlesize']= 24
mpl.rcParams['axes.grid']= False
mpl.rcParams['axes.labelsize'] = 22
mpl.rcParams['axes.labelpad'] = 0.5
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.markersize'] = 10
mpl.rcParams['lines.markeredgewidth'] = 2
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize']= 18
mpl.rcParams['legend.fontsize']= 20


save = False

# Plotting here
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(8 * 3, 6 * 1), constrained_layout=False)

colors1 = cm.Blues(np.linspace(0.6,0.9,n_metaruns))
colors2 = cm.Greens(np.linspace(0.6,0.9,n_metaruns))

shapes = ['o', 'v', 's']
# Preprocessing here

for nm in range(0,n_metaruns):
  monitor_EnKF = monitor_EnKFs[nm]
  monitor_KF = monitor_KFs[nm]
  monitor_PF = monitor_PFs[nm]
  p1 = torch.abs(monitor_EnKF - monitor_KF)**2
  p1_new = p1.detach().clone()
  p1_new[:,:,0] = p1[:,:,0] / monitor_KF[0,0,0]**2
  p1_new[:,:,1] = torch.mean(p1[:,:,1:1+a_dim], dim=-1) / torch.mean(monitor_KF[0,0,1:1+a_dim]**2)
  p1_new[:,:,2] = torch.mean(p1[:,:,1+a_dim:], dim=-1) / torch.mean(monitor_KF[0,0,1+a_dim:]**2)
  p2 = torch.abs(monitor_PF - monitor_KF)**2
  p2_new = p2.detach().clone()
  p2_new[:,:,0] = p2[:,:,0] / monitor_KF[0,0,0]**2
  p2_new[:,:,1] = torch.mean(p2[:,:,1:1+a_dim], dim=-1) / torch.mean(monitor_KF[0,0,1:1+a_dim]**2)
  p2_new[:,:,2] = torch.mean(p2[:,:,1+a_dim:], dim=-1) / torch.mean(monitor_KF[0,0,1+a_dim:]**2)
  m1 = torch.mean(p1_new, dim=0) ** 0.5
  m2 = torch.mean(p2_new, dim=0) ** 0.5
  # m2, s2 = utils.mean_and_std(p2, 0)




  axes[0].plot(N_ensems, m1[:,0], shapes[nm]+'-',mfc='w', color=colors1[nm], label=rf"EnKF, $d_x={x_dims[nm]}$")
  axes[0].plot(N_ensems, m2[:,0], shapes[nm]+'-',mfc='w', color=colors2[nm], label=rf"PF, $d_x={x_dims[nm]}$")

  axes[1].plot(N_ensems, m1[:,1], shapes[nm]+'-',mfc='w', color=colors1[nm], label=f"EnKF, $d_x={x_dims[nm]}$")
  axes[1].plot(N_ensems, m2[:,1], shapes[nm]+'-',mfc='w', color=colors2[nm], label=f"PF, $d_x={x_dims[nm]}$")


  axes[2].plot(N_ensems, m1[:,2], shapes[nm]+'-',mfc='w', color=colors1[nm], label=f"EnKF, $d_x={x_dims[nm]}$")
  axes[2].plot(N_ensems, m2[:,2], shapes[nm]+'-',mfc='w', color=colors2[nm], label=f"PF, $d_x={x_dims[nm]}$")


x = N_ensems
axes[0].plot(x, 0.05/np.power(x, 0.5), 'r--', linewidth=3, label=r"$O(N^{-1/2})$")
axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlabel(r"$N$")
axes[0].set_ylabel(r"$L^2$ estimation error (${\mathcal{L}}$)")
# axes[0].legend(loc='lower center',bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=False, shadow=False)



axes[1].plot(x, 2/4/np.power(x, 0.5), 'r--', linewidth=3, label=r"$O(N^{-1/2})$")
axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlabel(r"$N$")
axes[1].set_ylabel(r"$L^2$ estimation error ($\nabla_\alpha {\mathcal{L}}$)")

leg=axes[1].legend(loc='lower center',bbox_to_anchor=(0.5, -0.36),
          ncol=4, fancybox=False, shadow=False)
# leg._legend_box.align = "right"


axes[2].plot(x, 4/6/np.power(x, 0.5), 'r--', linewidth=3, label=r"$O(N^{-1/2})$")
axes[2].set_xscale('log')
axes[2].set_yscale('log')
axes[2].set_xlabel(r"$N$")
axes[2].set_ylabel(r"$L^2$ estimation error ($\nabla_\beta {\mathcal{L}}$)")

# axes[2].legend(loc='lower left')

# Adjustments here
if save:
  plt.savefig(f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/20_40_80_off.pdf", bbox_inches='tight')
# Out:
# time: 2.46 s (started: 2021-06-18 18:12:19 +00:00)

# %%
importlib.reload(DAModel)
importlib.reload(NNModel)
importlib.reload(Noise)
importlib.reload(utils)

# seed = 42
# torch.manual_seed(seed)
# np.random.seed(seed)
# random.seed(seed)


# N_ensems = np.rint(np.power(1.2, np.arange(18,50))).astype(int) 
N_ensems = 25 * 2 ** (np.arange(0, 14))
n_epochs = N_ensems.shape[0]

n_runs= 30
# n_epochs = x_axis.shape[0]

x_dims = [80, 80, 80, 80]
localization_radius = [None, 5, 10, 20]
n_metaruns = len(x_dims)
monitor_EnKFs = []
monitor_KFs = []
monitor_PFs = []

for nm in range(0):
  x_dim = x_dims[nm]
  # if nm == 0:
  #   x_dim = x_dims[ne]
  # true_a = torch.tensor(0.42)
  # true_ode_func = NNModel.Linear_ODE_single_var(x_dim, true_a).to(device)
  # true_a = torch.tensor([0.3, 0.4,0.1,0.15,0.05])
  true_a = torch.tensor([0.3, 0.6,0.1])
  a_dim = true_a.shape[0]
  true_ode_func = NNModel.Linear_ODE_diag(x_dim, true_a).to(device)

  u0 = 2*torch.ones(x_dim, device=device)
  t0 = 0.
  t_obs_step = 1.
  t_obs_end = 10.
  t_obs = torch.arange(t0, t_obs_end+t_obs_step, t_obs_step)[1:].to(device)

  # q = 0.5
  # model_Q_true = Noise.AddGaussian(x_dim, torch.sqrt(torch.tensor(q)), "scalar")
  q = 0.5
  model_Q_true = Noise.AddGaussian(x_dim, torch.sqrt(torch.tensor(q)), "scalar", q_shape=torch.tensor(1.))

  init_m = torch.zeros(x_dim, device=device)
  init_C_param = Noise.AddGaussian(x_dim, 4*torch.eye(x_dim), "full")

  indices = [i for i in range(x_dim)]
  # indices = [0]
  y_dim = len(indices)
  H_true = torch.eye(x_dim)[indices]
  true_obs_func = NNModel.Linear(x_dim, y_dim, H_true).to(device)

  noise_R_true = Noise.AddGaussian(y_dim, torch.sqrt(torch.tensor(0.5)), "scalar")

  seed = 42
  torch.manual_seed(seed)
  np.random.seed(seed)
  random.seed(seed)

  with torch.no_grad():
    out, y_obs, out_intermediate, t_intermediate = DEModel.generate_data(true_ode_func, true_obs_func, t_obs, u0, model_Q_true, noise_R_true, 
                                                  device=device, ode_method='euler', ode_options=dict(step_size=t_obs_step), adjoint=False, save_intermediate_step=True, t0=t0, time_varying_obs=False)

  monitor_EnKF = torch.zeros(n_runs, n_epochs, 3+a_dim)
  monitor_PF = torch.zeros(n_runs, n_epochs, 3+a_dim)
  monitor_KF = torch.zeros(1, n_epochs, 3+a_dim)

  for ne in range(n_epochs):
    print(ne,end='') 

    N_ensem = N_ensems[ne]
    # test_a = torch.tensor([0.3, 0.4,0.1,0.15,0.05])
    test_a = torch.tensor([0.5, 0.5, 0.5])
    test_ode_func = NNModel.Linear_ODE_diag(x_dim, test_a).to(device)
    q = 1
    test_model_Q = Noise.AddGaussian(x_dim, torch.sqrt(torch.tensor(q)), "scalar", q_shape=torch.tensor(0.1))

    enkf_kwargs = dict(ode_method='euler', ode_options=dict(step_size=t_obs_step), adjoint=False, save_intermediate_step=True, smooth_lag=0, t0=t0, 
          var_inflation=None, localization_radius=localization_radius[nm], compute_likelihood=True, likelihood_warmup=0, 
          linear_obs=True, time_varying_obs=False, save_first=True, simulation_type=0)

    for nr in range(n_runs):
      X, X_track, X_intermediate, neg_log_likelihood = DAModel.EnKF(test_ode_func, true_obs_func, t_obs, y_obs.unsqueeze(-2).repeat(1,1,1), N_ensem=N_ensem, init_m=init_m, init_C_param=init_C_param, model_Q_param=test_model_Q, noise_R_param=noise_R_true, device=device, detach_every=None, Cf_track=None, **enkf_kwargs)
      neg_log_likelihood.mean().backward()
      monitor_EnKF[nr,ne,0] = neg_log_likelihood.detach()
      monitor_EnKF[nr,ne,1:1+a_dim] = test_ode_func.a.grad.detach()
      monitor_EnKF[nr,ne,1+a_dim] = test_model_Q.post_grad().item()
      monitor_EnKF[nr,ne,2+a_dim] = test_model_Q.q_shape.grad.item()
      test_ode_func.a.grad.zero_()
      test_model_Q.q.grad.zero_()
      test_model_Q.q_shape.grad.zero_()

    if nm == 0:
      m_track, C_track, Cf_track, neg_log_likelihood = DAModel.KF(test_ode_func, true_obs_func, t_obs, y_obs, init_m, init_C_param, test_model_Q, noise_R_true, device, **enkf_kwargs)
      neg_log_likelihood.mean().backward()
      monitor_KF[0,ne,0] = neg_log_likelihood.detach()
      monitor_KF[0,ne,1:1+a_dim] = test_ode_func.a.grad.detach()
      monitor_KF[0,ne,1+a_dim] = test_model_Q.post_grad().item()
      monitor_KF[0,ne,2+a_dim] = test_model_Q.q_shape.grad.item()
      test_ode_func.a.grad.zero_()
      test_model_Q.q.grad.zero_()
      test_model_Q.q_shape.grad.zero_()

      for nr in range(n_runs):
        X, w, X_track, X_intermediate, w_track, w_intermediate, neg_log_likelihood = DAModel.BootstrapPF(test_ode_func, true_obs_func, t_obs, y_obs.unsqueeze(-2).repeat(1,1,1), N_ensem=N_ensem, init_m=init_m, init_C_param=init_C_param, model_Q_param=test_model_Q, noise_R_param=noise_R_true, device=device, proposal='optimal', adaptive_resampling=False, detach_every=None, **enkf_kwargs)
        # X, X_track, X_intermediate, neg_log_likelihood = DAModel.EnKF(test_ode_func, true_obs_func, t_obs, y_obs.unsqueeze(-2).repeat(1,1,1), N_ensem=N_ensem, init_m=init_m, init_C_param=init_C_param, model_Q_param=model_Q_true, noise_R_param=noise_R_true, device=device, detach_every=None, Cf_track=Cf_track, **enkf_kwargs)
        neg_log_likelihood.mean().backward()
        monitor_PF[nr,ne,0] = neg_log_likelihood.detach()
        monitor_PF[nr,ne,1:1+a_dim] = test_ode_func.a.grad.detach()
        monitor_PF[nr,ne,1+a_dim] = test_model_Q.post_grad().item()
        monitor_PF[nr,ne,2+a_dim] = test_model_Q.q_shape.grad.item()
        test_ode_func.a.grad.zero_()
        test_model_Q.q.grad.zero_()
        test_model_Q.q_shape.grad.zero_()

  monitor_EnKFs.append(monitor_EnKF)
  monitor_KFs.append(monitor_KF)
  monitor_PFs.append(monitor_PF)
# Out:
# time: 211 ms (started: 2021-06-21 23:57:07 +00:00)

# %%
enkf_kwargs = dict(ode_method='euler', ode_options=dict(step_size=t_obs_step), adjoint=False, save_intermediate_step=True, smooth_lag=0, t0=t0, 
          var_inflation=None, localization_radius=5, compute_likelihood=True, likelihood_warmup=0, 
          linear_obs=True, time_varying_obs=False, save_first=True, simulation_type=0)

test_a = torch.tensor([0.3, 0.6, 0.1])
test_ode_func = NNModel.Linear_ODE_diag(x_dim, test_a).to(device)
q = 0.5
test_model_Q = Noise.AddGaussian(x_dim, torch.sqrt(torch.tensor(q)), "scalar", q_shape=torch.tensor(1.))
X, X_track, X_intermediate, neg_log_likelihood = DAModel.EnKF(test_ode_func, true_obs_func, t_obs, y_obs.unsqueeze(-2).repeat(1,1,1), N_ensem=25, init_m=init_m, init_C_param=init_C_param, model_Q_param=test_model_Q, noise_R_param=noise_R_true, device=device, detach_every=None, Cf_track=None, **enkf_kwargs)
utils.plot_filter(t_obs, out, X_track[1:,0], name="Ensemble", plot_all=False, compare_F_S=False, fig_num_limit=5)

# %%
torch.save({'monitor_EnKFs':monitor_EnKFs, 'monitor_KFs':monitor_KFs, 'monitor_PFs':monitor_PFs, 'x_dims':x_dims, 'N_ensems':N_ensems}, 
           f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/80_loc_off")
# Out:
# time: 445 ms (started: 2021-06-20 00:35:30 +00:00)

# %%
d = torch.load(f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/80_loc_off")
monitor_EnKFs = d['monitor_EnKFs']
monitor_KFs = d['monitor_KFs']
monitor_PFs = d['monitor_PFs']
x_dims = d['x_dims']
N_ensems = d['N_ensems']
# Out:
# time: 573 ms (started: 2021-06-21 23:57:07 +00:00)

# %%
a_dim=3
# Out:
# time: 6.57 ms (started: 2021-06-22 00:00:41 +00:00)

# %%
importlib.reload(utils)
mpl.rc_file_defaults()
rc('font', **{'family':'serif','serif':'Computer Modern'})
rc('text', usetex=True)
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']
mpl.rcParams['axes.titlesize']= 24
mpl.rcParams['axes.grid']= False
mpl.rcParams['axes.labelsize'] = 22
mpl.rcParams['axes.labelpad'] = 0.5
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.markersize'] = 10
mpl.rcParams['lines.markeredgewidth'] = 2
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize']= 18
mpl.rcParams['legend.fontsize']= 20


save=True

# Plotting here
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(8 * 3, 6 * 1), constrained_layout=False)

colors1 = cm.Blues(np.linspace(0.8,0.9,n_metaruns))
colors1 = [cm.Blues(0.9), cm.Purples(0.9), cm.GnBu(0.9), cm.GnBu(0.9)]
colors2 = cm.Greens(np.linspace(0.8,0.9,n_metaruns))

shapes = ['s', 'v', '^', 'o']
# Preprocessing here

p=2
for nm in [0, 1, 3]:
  if nm == 0:
    monitor_EnKF = monitor_EnKFs[nm] # (n_runs, n_epoch, n_monitor)
    monitor_KF = monitor_KFs[nm]
    p1 = torch.abs(monitor_EnKF - monitor_KF)**2
    p1_new = p1.detach().clone()
    p1_new[:,:,0] = p1[:,:,0]**(p/2) / torch.abs(monitor_KF[0,0,0])**p # (n_runs, n_epoch)
    p1_new[:,:,1] = torch.sum(p1[:,:,1:1+a_dim], dim=-1)**(p/2) / torch.sum(torch.abs(monitor_KF[0,0,1:1+a_dim])**2)**(p/2) # (n_runs, n_epoch)
    p1_new[:,:,2] = torch.sum(p1[:,:,1+a_dim:], dim=-1)**(p/2) / torch.sum(torch.abs(monitor_KF[0,0,1+a_dim:])**2)**(p/2) # (n_runs, n_epoch)
    m1 = torch.mean(p1_new, dim=0) ** (1/p)
  
    monitor_PF = monitor_PFs[nm]
    p2 = torch.abs(monitor_PF - monitor_KF)**2
    p2_new = p2.detach().clone()
    p2_new[:,:,0] = p2[:,:,0]**(p/2) / torch.abs(monitor_KF[0,0,0])**p
    p2_new[:,:,1] = torch.sum(p2[:,:,1:1+a_dim], dim=-1)**(p/2) / torch.sum(torch.abs(monitor_KF[0,0,1:1+a_dim])**2)**(p/2)
    p2_new[:,:,2] = torch.sum(p2[:,:,1+a_dim:], dim=-1)**(p/2) / torch.sum(torch.abs(monitor_KF[0,0,1+a_dim:])**2)**(p/2)
    m2 = torch.mean(p2_new, dim=0) ** (1/p)
    # m2, s2 = utils.mean_and_std(p2, 0)
  else:
    monitor_EnKF = monitor_EnKFs[nm] # (n_runs, n_epoch, n_monitor)
    p1 = torch.abs(monitor_EnKF - monitor_KF)**2
    p1_new = p1.detach().clone()
    p1_new[:,:,0] = p1[:,:,0]**(p/2) / torch.abs(monitor_KF[0,0,0])**p # (n_runs, n_epoch)
    p1_new[:,:,1] = torch.sum(p1[:,:,1:1+a_dim], dim=-1)**(p/2) / torch.sum(torch.abs(monitor_KF[0,0,1:1+a_dim])**2)**(p/2) # (n_runs, n_epoch)
    p1_new[:,:,2] = torch.sum(p1[:,:,1+a_dim:], dim=-1)**(p/2) / torch.sum(torch.abs(monitor_KF[0,0,1+a_dim:])**2)**(p/2) # (n_runs, n_epoch)
    m1 = torch.mean(p1_new, dim=0) ** (1/p)



  if nm == 0:
    axes[0].plot(N_ensems, m1[:,0], shapes[nm]+'-',mfc='w', color=colors1[nm], label=rf"EnKF no taper")
    axes[0].plot(N_ensems, m2[:,0], shapes[nm]+'-',mfc='w', color=colors2[nm], label=rf"PF")
  else:
    axes[0].plot(N_ensems, m1[:,0], shapes[nm]+'-',mfc='w', color=colors1[nm], label=rf"EnKF, taper={localization_radius[nm]}")

  if nm == 0:
    axes[1].plot(N_ensems, m1[:,1], shapes[nm]+'-',mfc='w', color=colors1[nm], label=f"EnKF, no taper")
    axes[1].plot(N_ensems, m2[:,1], shapes[nm]+'-',mfc='w', color=colors2[nm], label=f"PF")
  else:
    axes[1].plot(N_ensems, m1[:,1], shapes[nm]+'-',mfc='w', color=colors1[nm], label=rf"EnKF, taper={localization_radius[nm]}")


  if nm == 0:
    axes[2].plot(N_ensems, m1[:,2], shapes[nm]+'-',mfc='w', color=colors1[nm], label=f"EnKF, no taper")
    axes[2].plot(N_ensems, m2[:,2], shapes[nm]+'-',mfc='w', color=colors2[nm], label=f"PF")
  else:
    axes[2].plot(N_ensems, m1[:,2], shapes[nm]+'-',mfc='w', color=colors1[nm], label=rf"EnKF, taper={localization_radius[nm]}")





x = N_ensems
axes[0].plot(x, 0.03*1.2/np.power(x, 0.5), 'r--', linewidth=3, label=r"$O(N^{-1/2})$")
axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlabel(r"$N$")
axes[0].set_ylabel(r"$L^2$ estimation error (${\mathcal{L}}$)")


axes[1].plot(x, 3/5/np.power(x, 0.5), 'r--', linewidth=3, label=r"$O(N^{-1/2})$")
axes[1].set_xscale('log')
axes[1].set_yscale('log')
# axes[1].legend(loc='lower left')
handles, labels = axes[1].get_legend_handles_labels()
legend_order=[0,3,2,1,4]
axes[1].legend([handles[idx] for idx in legend_order],[labels[idx] for idx in legend_order],loc='lower center',bbox_to_anchor=(0.5, -0.36),
          ncol=3, fancybox=False, shadow=False)
axes[1].set_xlabel(r"$N$")
axes[1].set_ylabel(r"$L^2$ estimation error ($\nabla_\alpha {\mathcal{L}}$)")



axes[2].plot(x, 2/3/np.power(x, 0.5), 'r--', linewidth=3, label=r"$O(N^{-1/2})$")
axes[2].set_xscale('log')
axes[2].set_yscale('log')
# axes[2].legend(loc='lower left')
axes[2].set_xlabel(r"$N$")
axes[2].set_ylabel(r"$L^2$ estimation error ($\nabla_\beta {\mathcal{L}}$)")

# Adjustments here
if save:
  plt.savefig(f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/80_loc_off.pdf", bbox_inches='tight')
# Out:
# time: 3.56 s (started: 2021-06-22 00:07:38 +00:00)

# %%
cm.Blues(0.7)
# Out:
# (0.1791464821222607, 0.49287197231833907, 0.7354248366013072, 1.0)
# time: 11.5 ms (started: 2021-06-17 22:11:05 +00:00)

# %%
utils.plot_dynamic(t_obs, out, t_obs=None, y_obs=None, fig_num_limit=5, text="test", contour_plot=True)
# utils.plot_filter(t_obs, out, (w_track[1:,0],X_track[1:,0]), name="Particle", plot_all=False, compare_F_S=False, fig_num_limit=5)
# utils.plot_filter(t_obs, out, X_track[1:,0], name="Ensemble", plot_all=False, compare_F_S=False, fig_num_limit=5)
# Out:
# time: 5.92 s (started: 2021-06-16 21:34:01 +00:00)

# %%
importlib.reload(utils)
mpl.rc_file_defaults()
rc('font', **{'family':'serif','serif':'Computer Modern'})
rc('text', usetex=True)
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']
mpl.rcParams['axes.titlesize']= 24
mpl.rcParams['axes.grid']= False
mpl.rcParams['axes.labelsize'] = 17
mpl.rcParams['axes.labelpad'] = 1
# mpl.rcParams['lines.linewidth'] = 10
mpl.rcParams['lines.markersize'] = 10
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize']= 13
mpl.rcParams['legend.fontsize']= 16


# Preprocessing here


p1 = torch.abs(monitor_EnKF - monitor_KF)**2
p1_new = p1.detach().clone()
p1_new[:,:,0] = p1[:,:,0]
p1_new[:,:,1] = torch.mean(p1[:,:,1:1+a_dim], dim=-1)
p1_new[:,:,2] = torch.mean(p1[:,:,1+a_dim:], dim=-1)
p2 = torch.abs(monitor_PF - monitor_KF)**2
p2_new = p2.detach().clone()
p2_new[:,:,0] = p2[:,:,0]
p2_new[:,:,1] = torch.mean(p2[:,:,1:1+a_dim], dim=-1)
p2_new[:,:,2] = torch.mean(p2[:,:,1+a_dim:], dim=-1)
m1 = torch.mean(p1_new, dim=0) ** 0.5
m2 = torch.mean(p2_new, dim=0) ** 0.5
# m2, s2 = utils.mean_and_std(p2, 0)

# Plotting here
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(8 * 3, 6 * 1), constrained_layout=False)

colors1 = cm.Blues(np.linspace(0.5,0.7,n_runs+1))
colors2 = cm.Greens(np.linspace(0.5,0.7,n_runs+1))
axes[0].plot(N_ensems, m1[:,0], color=colors1[-1], label="EnKF")
axes[0].plot(N_ensems, m2[:,0], color=colors2[-1], label="PF")

x = N_ensems
axes[0].plot(x, 12/np.power(x, 0.5))
axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].legend(loc='upper right')

axes[1].plot(N_ensems, m1[:,1], color=colors1[-1], label="EnKF")
axes[1].plot(N_ensems, m2[:,1], color=colors2[-1], label="PF")

axes[1].plot(x, 60/np.power(x, 0.5))
axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].legend(loc='upper right')

axes[2].plot(N_ensems, m1[:,2], color=colors1[-1], label="EnKF")
axes[2].plot(N_ensems, m2[:,2], color=colors2[-1], label="PF")

axes[2].plot(x, 60/np.power(x, 0.5))
axes[2].set_xscale('log')
axes[2].set_yscale('log')
axes[2].legend(loc='upper right')

# Adjustments here
# Out:
# time: 2.32 s (started: 2021-06-15 09:04:18 +00:00)

# %%
importlib.reload(utils)

mpl.rc_file_defaults()
rc('font', **{'family':'serif','serif':'Computer Modern'})
rc('text', usetex=True)
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']
mpl.rcParams['axes.titlesize']= 24
mpl.rcParams['axes.grid']= True
mpl.rcParams['axes.labelsize'] = 17
mpl.rcParams['axes.labelpad'] = 1
# mpl.rcParams['lines.linewidth'] = 10
mpl.rcParams['lines.markersize'] = 10
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize']= 13
mpl.rcParams['legend.fontsize']= 16


def custom_axes(axes,ax_d):
  axes[0,0].set_xlabel(r"$d_x$")
  axes[1,0].set_xlabel(r"$d_x$")
  axes[0,1].set_xlabel(r"$T$")
  axes[1,1].set_xlabel(r"$T$")
  axes[0,2].set_xlabel(r"$\beta^*$")
  axes[1,2].set_xlabel(r"$\beta^*$")
  axes[0,0].set_ylabel(r"Loglikelihood Estimate ($\widehat l-l$)")
  axes[1,0].set_ylabel(r"Gradient Estimate ($\nabla_\alpha \:\widehat l-\nabla_\alpha \: l$)")
  for ax in axes[0]:
    ax.legend(loc='lower left')
  for ax in axes[1]:
    ax.legend(loc='upper left')
  
  # axes[0,0].set_ylim(-300000,50000)
  # axes[1,0].set_ylim(-50, 50)
  return

save_location=None
load_location=None
# save_location = f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/T_dx_beta"
# load_location = f"/content/drive/MyDrive/project_Yuming/codes/final_figures/Linear/T_dx_beta"

# monitor_res = [monitor_KF,monitor_EnKF, monitor_PF]
monitor_res = [monitor_EnKF-monitor_KF,monitor_PF-monitor_KF]
# monitor_res = [(monitor_EnKF-monitor_KF)/torch.abs(monitor_KF),(monitor_PF-monitor_KF)/torch.abs(monitor_KF)]
# methods = [ r"Truth",r"EnKF",  r"PF",]
methods = [ r"EnKF",r"PF"]
# titles = ["Likelihood estimate", "grad"]
titles = [None, None, None, None, None, None]
truths = [None,None]
logscale={}#{0,1,2}
logscalex={2,5}
legend_order=[0,1]
utils.plot_monitor_res_new(monitor_res, methods, titles, truths, logscale, logscalex,legend_order=legend_order, error_bar=True, n_cols=3,subplot_width=7, subplot_height=5,linewidth=2, x_axiss=None, custom_axes=custom_axes, save_location=save_location, load_location=load_location)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-5d269f5c27ac> in <module>()
#      50 logscalex={2,5}
#      51 legend_order=[0,1]
# ---> 52 utils.plot_monitor_res_new(monitor_res, methods, titles, truths, logscale, logscalex,legend_order=legend_order, error_bar=True, n_cols=3,subplot_width=7, subplot_height=5,linewidth=2, x_axiss=None, custom_axes=custom_axes, save_location=save_location, load_location=load_location)
#
# /content/drive/MyDrive/project_Yuming/codes/utils.py in plot_monitor_res_new(monitor_res, methods, titles, truths, logscale, logscalex, truths_legends, truths2, truths2_legends, plot_truth_first, start_from_one, legend_order, groups, error_bar, error_bar_style, plots_to_show, n_cols, subplot_width, subplot_height, subplot_groups, ax_d, linewidth, colors_list, custom_axes, x_axiss, save_location, file_name, load_location)
#     289
#     290   if custom_axes is not None:
# --> 291     custom_axes(axes, ax_d)
#     292
#     293   if save_location is not None:
#
# <ipython-input-7-5d269f5c27ac> in custom_axes(axes, ax_d)
#      18 def custom_axes(axes,ax_d):
#      19   axes[0,0].set_xlabel(r"$d_x$")
# ---> 20   axes[1,0].set_xlabel(r"$d_x$")
#      21   axes[0,1].set_xlabel(r"$T$")
#      22   axes[1,1].set_xlabel(r"$T$")
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# time: 4.07 s (started: 2021-06-14 22:23:48 +00:00)

# %%
x_axiss=[x_axiss[0], x_axiss[3]]
# Out:
# time: 1.69 ms (started: 2021-06-08 17:12:35 +00:00)

# %% [markdown]
# #2. Learning

# %%
monitor_EnKF_new[0,-3,0]
# print(monitor_KF_truths)
# Out:
# tensor(0.)
# time: 7.72 ms (started: 2021-05-18 05:52:46 +00:00)
